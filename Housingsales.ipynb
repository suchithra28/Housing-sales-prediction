# %%
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df=pd.read_csv("train.csv")

# %%
d=pd.read_csv('test.csv')
#d2['Id'].to_csv('idj.csv')

# %%
d.head()
# Out:
#      Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0  1461          20       RH  ...    2010        WD        Normal
# 1  1462          20       RL  ...    2010        WD        Normal
# 2  1463          60       RL  ...    2010        WD        Normal
# 3  1464          60       RL  ...    2010        WD        Normal
# 4  1465         120       RL  ...    2010        WD        Normal
#
# [5 rows x 80 columns]

# %%
df.to_csv('train.csv')

# %%
d.to_csv('test.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
c=[]
for i in df.columns:
  if(df[i].dtype=="object")
  print(i)
# Out:
#   File "<ipython-input-46-3c8ddc7500bb>", line 3
#     if(df[i].dtype==object)
#                            ^
# SyntaxError: invalid syntax

# %%
k=df.select_dtypes(exclude=['int'])

# %%
l=[]

# %%
for i in k.columns:
  l.append([i])

# %%
l
# Out:
# [['MSZoning'],
#  ['Street'],
#  ['Alley'],
#  ['LotShape'],
#  ['LandContour'],
#  ['Utilities'],
#  ['LotConfig'],
#  ['LandSlope'],
#  ['Neighborhood'],
#  ['Condition1'],
#  ['Condition2'],
#  ['BldgType'],
#  ['HouseStyle'],
#  ['RoofStyle'],
#  ['RoofMatl'],
#  ['Exterior1st'],
#  ['Exterior2nd'],
#  ['MasVnrType'],
#  ['MasVnrArea'],
#  ['ExterQual'],
#  ['ExterCond'],
#  ['Foundation'],
#  ['BsmtQual'],
#  ['BsmtCond'],
#  ['BsmtExposure'],
#  ['BsmtFinType1'],
#  ['BsmtFinType2'],
#  ['Heating'],
#  ['HeatingQC'],
#  ['CentralAir'],
#  ['Electrical'],
#  ['KitchenQual'],
#  ['Functional'],
#  ['FireplaceQu'],
#  ['GarageType'],
#  ['GarageYrBlt'],
#  ['GarageFinish'],
#  ['GarageQual'],
#  ['GarageCond'],
#  ['PavedDrive'],
#  ['PoolQC'],
#  ['Fence'],
#  ['MiscFeature'],
#  ['SaleType'],
#  ['SaleCondition']]

# %%
d.head()
# Out:
#    Unnamed: 0    Id  MSSubClass MSZoning  LotFrontage  ...  WdShing Av Gd Mn  No
# 0           0  1461          20       RH           80  ...        0  0  0  0   1
# 1           1  1462          20       RL           81  ...        0  0  0  0   1
# 2           2  1463          60       RL           74  ...        0  0  0  0   1
# 3           3  1464          60       RL           78  ...        0  0  0  0   1
# 4           4  1465         120       RL           43  ...        0  0  0  0   1
#
# [5 rows x 158 columns]

# %%
d['Id'].to_csv('id1.csv')

# %%
b=df.corr()
b
# Out:
#              Unnamed: 0        Id  MSSubClass  ...        Gd        Mn        No
# Unnamed: 0     1.000000  1.000000    0.011156  ... -0.005336  0.022732 -0.026357
# Id             1.000000  1.000000    0.011156  ... -0.005336  0.022732 -0.026357
# MSSubClass     0.011156  0.011156    1.000000  ...  0.016593  0.003846 -0.061173
# LotFrontage   -0.004728 -0.004728   -0.373345  ...  0.165104  0.032527 -0.135168
# LotArea       -0.033226 -0.033226   -0.139781  ...  0.278062  0.005495 -0.164645
# ...                 ...       ...         ...  ...       ...       ...       ...
# 0             -0.002143 -0.002143    0.015555  ... -0.051966 -0.047574 -0.224122
# Av             0.023245  0.023245    0.058105  ... -0.134258 -0.122911 -0.579033
# Gd            -0.005336 -0.005336    0.016593  ...  1.000000 -0.092515 -0.435836
# Mn             0.022732  0.022732    0.003846  ... -0.092515  1.000000 -0.399000
# No            -0.026357 -0.026357   -0.061173  ... -0.435836 -0.399000  1.000000
#
# ...

# %%
b.to_csv('corr1.csv')

# %%
h=pd.read_csv('oof.csv')

# %%
g=[]

# %%
g.remove('Ex', 'Y', 'RL', '2Story.1')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-149-7dc319d23f8d> in <module>()
# ----> 1 g.remove('Ex', 'Y', 'RL', '2Story.1')
#
# TypeError: remove() takes exactly one argument (4 given)

# %%
'Ex', 'Y', 'RL', '2Story.1'

# %%
for i in h.index:
  if(h['OverallQual'][i]!='')
  g.append(h["OverallQual"][i])

# %%
g
# Out:
# ['GrLivArea',
#  'GarageCars',
#  'GarageArea',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  'FullBath',
#  'TotRmsAbvGrd',
#  'YearBuilt',
#  'YearRemodAdd',
#  'PConc',
#  'MasVnrArea',
#  'Fireplaces',
#  'BsmtFinSF1',
#  'LotFrontage',
#  'WoodDeckSF',
#  'Gd',
#  '2ndFlrSF',
#  'OpenPorchSF',
#  'Gd',
#  'VinylSd',
#  'HalfBath',
#  'LotArea',
#  '2Story',
#  'Hip',
#  'BsmtFullBath',
#  'IR1',
#  'BsmtUnfSF',
#  'WdShngl',
#  'BedroomAbvGr',
#  'CulDSac',
#  '1Fam',
#  'Av',
#  'CemntBd',
#  'HLS',
#  'Norm',
#  'ScreenPorch',
#  'OverallQual']

# %%
g.append('OverallQual')

# %%
dummy_variable_1 = pd.get_dummies(df["BsmtExposure"])
c.append("BsmtExposure")
df = pd.concat([df, dummy_variable_1], axis=1)
df.drop('BsmtExposure',axis=1,inplace=True)
#dummy_variable_1.head(10)
#dummy_variable_1.rename(columns={}, inplace=True)
#dummy_variable_1.head()
#drop original column "fuel-type" from "df"

# %%
for i in l:
  dummy_variable_1 = pd.get_dummies(d[i])
  d = pd.concat([d, dummy_variable_1], axis=1)
  d.drop(i,axis=1,inplace=True)
#dummy_variable_1.head(10)
#dummy_variable_1.rename(columns={}, inplace=True)
#dummy_variable_1.head()
#drop original column "fuel-type" from "df"
#c.append("BsmtExposure")

# %%
d.head()
# Out:
#      Id  MSSubClass  ...  SaleCondition_Normal  SaleCondition_Partial
# 0  1461          20  ...                     1                      0
# 1  1462          20  ...                     1                      0
# 2  1463          60  ...                     1                      0
# 3  1464          60  ...                     1                      0
# 4  1465         120  ...                     1                      0
#
# [5 rows x 269 columns]

# %%
h=df.corr()

# %%
cd.fillna(0)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  ...  Alloca Family Normal Partial
# 0     1461          20       RH           80  ...       0      0      1       0
# 1     1462          20       RL           81  ...       0      0      1       0
# 2     1463          60       RL           74  ...       0      0      1       0
# 3     1464          60       RL           78  ...       0      0      1       0
# 4     1465         120       RL           43  ...       0      0      1       0
# ...    ...         ...      ...          ...  ...     ...    ...    ...     ...
# 1454  2915         160       RM           21  ...       0      0      1       0
# 1455  2916         160       RM           21  ...       0      0      0       0
# 1456  2917          20       RL          160  ...       0      0      0       0
# 1457  2918          85       RL           62  ...       0      0      1       0
# 1458  2919          60       RL           74  ...       0      0      1       0
#
# ...

# %%
d['LotFrontage'].isnull().value_counts()
# Out:
# False    1459
# Name: LotFrontage, dtype: int64

# %%
dfg=df.corr()
dfg
#dfg['SalePrice'].head()
#df['LotFrontage'].hist(bins=30,color='red',alpha=0.5)
# Out:
#              Unnamed: 0        Id  MSSubClass  ...   BuiltIn   CarPort    Detchd
# Unnamed: 0     1.000000  1.000000    0.011156  ... -0.015589 -0.017472  0.003919
# Id             1.000000  1.000000    0.011156  ... -0.015589 -0.017472  0.003919
# MSSubClass     0.011156  0.011156    1.000000  ...  0.077454  0.038889  0.062966
# LotFrontage   -0.004728 -0.004728   -0.373345  ...  0.080850  0.036494 -0.248609
# LotArea       -0.033226 -0.033226   -0.139781  ...  0.037552  0.009136 -0.126094
# ...                 ...       ...         ...  ...       ...       ...       ...
# Attchd         0.004024  0.004024   -0.154332  ... -0.307537 -0.095636 -0.729272
# Basment        0.041520  0.041520    0.041297  ... -0.029081 -0.009043 -0.068961
# BuiltIn       -0.015589 -0.015589    0.077454  ...  1.000000 -0.019946 -0.152097
# CarPort       -0.017472 -0.017472    0.038889  ... -0.019946  1.000000 -0.047298
# Detchd         0.003919  0.003919    0.062966  ... -0.152097 -0.047298  1.000000
#
# ...

# %%
dfg.to_csv('corr.csv')

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(n_neighbors=3)
d1=d[['LotFrontage','1stFlrSF','LotArea','GrLivArea','TotalBsmtSF']].dropna()
Y=d1['LotFrontage']
X=d1[['1stFlrSF','LotArea','GrLivArea','TotalBsmtSF']]

# %%
df2['RL'].isnull().value_counts()
# Out:
# False    1460
# Name: RL, dtype: int64

# %%
knn.fit(X, Y)
knn.score(X, Y)
# Out:
# 0.7339761098374449

# %%
d['LotFrontage'].fillna(0,inplace=True)

# %%
b=d['LotFrontage']
b.to_csv('Lotf11.csv')

# %%
yhat=knn.predict(d[['1stFlrSF','LotArea','GrLivArea','TotalBsmtSF']].dropna())

# %%
# Out:
# False    1458
# True        1
# Name: TotalBsmtSF, dtype: int64

# %%
y = pd.DataFrame(data=yhat,columns=["y"])

# %%
y.to_csv('yhat11.csv')

# %%
df33=pd.read_csv('df33.csv')

# %%
df3.to_csv('df33.csv')

# %%
for col in df33.index:
  if(df33['LotFrontage'][col]==0):
     df33['LotFrontage'][col]=df33['y'][col]
d['LotFrontage']=df33['LotFrontage']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
d['LotFrontage']=df3['LotFrontage']

# %%
#df.head(30)
#salecondotion needs dummy variables
#saletype too
#normalize yr sold

# %%
df.to_csv('train.csv')

# %%
d.drop('Alley',axis=1,inplace=True)

# %%
n=pd.read_csv('xxx.csv')
n
# Out:
#               MSSubClass
# 0            LotFrontage
# 1                LotArea
# 2            OverallQual
# 3            OverallCond
# 4              YearBuilt
# ..                   ...
# 67  Neighborhood_Crawfor
# 68  Neighborhood_Edwards
# 69  Neighborhood_Gilbert
# 70   Neighborhood_IDOTRR
# 71  Neighborhood_MeadowV
#
# [72 rows x 1 columns]

# %%
g=[]

# %%
for i in n.index:
  g.append(n['MSSubClass'][i])

# %%
g.append('MSSubClass')

# %%
df.fillna(0,inplace=True)

# %%
X=df[g]
Y=df['SalePrice']
#Y=df["SalePrice"]

# %%
X
# Out:
#       GrLivArea  GarageCars  GarageArea  ...  Norm  ScreenPorch  OverallQual
# 0           896         1.0       730.0  ...     1          120            5
# 1          1329         1.0       312.0  ...     1            0            6
# 2          1629         2.0       482.0  ...     1            0            5
# 3          1604         2.0       470.0  ...     1            0            6
# 4          1280         2.0       506.0  ...     1          144            8
# ...         ...         ...         ...  ...   ...          ...          ...
# 1454       1092         0.0         0.0  ...     1            0            4
# 1455       1092         1.0       286.0  ...     1            0            4
# 1456       1224         2.0       576.0  ...     1            0            5
# 1457        970         0.0         0.0  ...     1            0            5
# 1458       2000         3.0       650.0  ...     1            0            7
#
# [1459 rows x 38 columns]

# %%
d.fillna(0,inplace=True)

# %%
#SOME MODELS EMPLOYED

# %%
#RIDGECLASSIFIER
from sklearn.linear_model import RidgeClassifier
rc = RidgeClassifier().fit(X, Y)
rc.score(X, Y)
# Out:
# 0.15136986301369862

# %%
'''
#RIDGEREGRESSION
from sklearn.linear_model import Ridge
import numpy as np
rr = Ridge(alpha=0.0001)
rr.fit(X, Y)
rr.score(X,Y)
'''
# Out:
# '\n#RIDGEREGRESSION\nfrom sklearn.linear_model import Ridge\nimport numpy as np\nrr = Ridge(alpha=0.0001)\nrr.fit(X, Y)\nrr.score(X,Y)\n'

# %%
#RANDOM FOREST
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=20, random_state=0)
rf.fit(X,Y)
rf.score(X,Y)
# Out:
# 0.9992183478951913

# %%
yhat=rf.predict(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-186-70f5210a5e91> in <module>()
# ----> 1 yhat=rf.predict(X)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_forest.py in predict(self, X)
#     764         check_is_fitted(self)
#     765         # Check data
# --> 766         X = self._validate_X_predict(X)
#     767
#     768         # Assign chunk of trees to jobs
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_forest.py in _validate_X_predict(self, X)
#     410         check_is_fitted(self)
#     411
# --> 412         return self.estimators_[0]._validate_X_predict(X, check_input=True)
#     413
#     414     @property
#
# /usr/local/lib/python3.6/dist-packages/sklearn/tree/_classes.py in _validate_X_predict(self, X, check_input)
#     389                              "match the input. Model n_features is %s and "
# ...

# %%
y = pd.DataFrame(data=yhat,columns=["y"])

# %%
#y.to_csv('Fi11111.csv')
d['Id'].to_csv('id.csv')

# %%
#KERNEL SVM
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
ksvm = make_pipeline(StandardScaler(), SVC(gamma='auto'))
ksvm.fit(X,Y)
ksvm.score(X,Y)
# Out:
# 0.15616438356164383

# %%
#GRADIENT BOOSTING CLASSIFIER
from sklearn.ensemble import GradientBoostingRegressor
grc = GradientBoostingRegressor(n_estimators=100, learning_rate=1.0,max_depth=1, random_state=0).fit(X, Y)
grc.score(X,Y)
# Out:
# 0.9175146984981025

# %%
#ADA BOOST 
from sklearn.ensemble import AdaBoostClassifier
ada= AdaBoostClassifier(n_estimators=100, random_state=0)
ada.fit(X, Y)
ada.score(X, Y)
# Out:
# 0.8372615039281706

# %%
#K NEAREST NEIGHBOUR
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X, Y)
knn.score(X, Y)
# Out:
# 0.8361391694725028

# %%
#LOGISTIC REGRESSION
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(random_state=0).fit(X, Y)
lr.score(X,Y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# 0.792368125701459
